# %%
import pandas as pd
import numpy as np

df = pd.read_excel('node-edges.xlsx', header=None, )
df.columns = df.iloc[61]
df = df.iloc[0:30]

count = 0
for i in range(0, len(df.columns)):
    if (i % 2 != 0):
        df.columns.values[i] = ("%02d" % count) + ': Destination'
        count += 1
        
slices = []
for i in range(2, len(df.columns), 2):
    s = df.iloc[:, i-2:i]
    s = s.dropna()
    s = s[s.iloc[:,1] != '-'] # edges are marked at entrance AND destination, so missing values can be removed
    slices.append(s)
    
nodes = {}
edges = {}
for s in slices:
    node_name = s.iloc[:,0].name
    node_name = str.strip(node_name.split(':')[1]) # remove number and whitespace from name
    edges.update({e: node_name for e in s.iloc[:,0]})
    nodes.update({node_name: {'node_name': node_name,
                              'transitions': [{'entrance': e, 'destination': d} for e, d in s.iloc],
                              'visited':  False,
                              'previous': {}}})
    
class Graph:
    def __init__(self, nodes, edges):
        self.nodes = nodes
        self.edges = edges
        
graph = Graph(nodes, edges)

# %%
for s in slices:
    print(s.iloc[:,0].name)
# print([s.iloc[:,0].name for s in slices])
# Out:
# 00: Places of Interest
# 01: Oldale/Petalburg
# 02: Rustboro
# 03: Dewford
# 04: Slateport/Mauville/Verdanturf
# 05: Fallarbor/Lavaridge
# 06: Fortree/Lilycove
# 07: Mossdeep
# 08: Pacifidlog
# 09: Sootopolis
# 10: Petalburg Woods
# 11: Rusturf Tunnel
# 12: Granite Cave
# 13: Abandoned Ship
# 14: Jagged Pass
# 15: Meteor Falls
# 16: Mirage Tower
# 17: Route 119/123
# 18: Mt Pyre
# 19: Surf Hub
# 20: Magma Hideout
# 21: Aqua Hideout
# 22: Lilycove Contest Hall
# 23: Lilycove Department Store
# 24: Seafloor Cavern
# 25: Pokecenters
# 26: Victory Road
# 27: Waterfall Hub
# 28: E4 Pokecenter
# 29: Navel Rock
# 30: Dive Hub
# 31: Sky Pillar

# %%
slices_dict = {s.iloc[:,0].name : s for s in slices}

# TODO: Can this be generalized for dungeons?
def split_pokecenters(pokecenters):
    poke_sub = []
    # current_group = []
    current_prefix = ""
    start = 0
    end = 0
    for row in pokecenters.iloc:
        name = " ".join(row[0].split(" ", 2)[:2])
        if current_prefix == name:
            end += 1
        else:
            poke_sub.append(pokecenters.iloc[start:end])
            start = end
            end += 1
            current_prefix = name
    poke_sub.append(pokecenters.iloc[start:end])
    # The first iteration adds an empty dataframe. This removes it.
    return poke_sub[1:]


def process_pokecenters(key_str, slices_dict):
    poke_sub = split_pokecenters(slices_dict[key_str])
    key_num, key_name = key_str.split(':')
    for i, pc in enumerate(poke_sub):
        # new_key = key_num + '-' + str(i) + ':' + key_name
        new_key = key_str.replace(':', '-%d:' % i)
        pc = pc.rename({key_str: new_key}, axis='columns')
        slices_dict[new_key] = pc

        
process_pokecenters('25: Pokecenters', slices_dict)
slices_dict['25-8: Pokecenters']
list(slices_dict.values())
# Out:
# [61  00: Places of Interest          00: Destination
#  0    Rustboro Gym Interior  Pacifidlog Pokecenter W
#  2    Mauville Gym Interior            Verdanturf SE
#  3   Lavaridge Gym Interior     Seafloor Cavern R3 S
#  8                E4 Sidney       Dewford Pokecenter
#  10               E4 Glacia      Lilycove Pokecenter
#  11                E4 Drake              Fortree NNE
#  19                 Groudon   Department Store 3F Up
#  20                   Ho-oh              Fortree NNW
#  21                   Lugia          Mt Pyre 2F Down
#  24                  Regice            Sootopolis W2,
#  61 01: Oldale/Petalburg             01: Destination
#  3     Oldale Pokecenter  Aqua Hideout B1F S Room NW
#  4             Oldale SE            Slateport Museum
#  5         Petalburg Gym                Slateport SE
#  6        Petalburg Mart            Rusturf Tunnel S
#  9          Petalburg SE               Pacifidlog NW
#  10         Petalburg SW  Aqua Hideout B1F NE Room N,
#  61         02: Rustboro          02: Destination
#  6         Rustboro Mart       Petalburg Woods SE
#  9   Rustboro Pokecenter  Sootopolis Pokecenter S
#  10          Rustboro SE        Meteor Falls 1F E
#  13   Rustboro Cut House   Slateport Pokecenter S,
#  61           03: Dewford              03: Destination
#  0   Dewford Granite Cave           Mt Pyre 5F Hole SE
#  1            Dewford Gym       Aqua Hideout Warps 2 C
#  2           Dewford Hall         Lavaridge Pokecenter
#  3             Dewford NE              Mt Pyre 4F Hole
#  4     Dewford Pokecenter                    E4 Sidney
#  5             Dewford SE  Aqua Hideout B1F NE Room SW,
#  61 04: Slateport/Mauville/Verdanturf           04: Destination
#  0                  Slateport Contest       Aqua Hideout B2F NW
#  2                 Slateport Fan Club                  Strength
#  3                     Slateport Mart     Lilycove Pokecenter W
#  4                   Slateport Museum      Mt Pyre 2F Ceiling 1
#  5               Slateport Name Rater                      Dive
#  6               Slateport Pokecenter    Lavaridge Pokecenter S
#  7                       Slateport SE             Petalburg Gym
#  8                R109 Seashore House              R114 Lanette
#  9                  R110 Cycle Road S    Fallarbor Pokecenter W
#  12                           Daycare                  Dead-End
#  13                Mauville Bike Shop                  Dead-End
#  14                   Mauville Casino                  Dead-End
#  15                      Mauville Gym             Mt Pyre 3F Up
#  16                     Mauville Mart       Granite Cave B1F SE
#  17               Mauville Pokecenter     Abandoned Ship B1F SW
#  18                        Mauville S     Rustboro Pokecenter S
#  19                       Mauville SE                  Dead-End
#  20                 R110 Cycle Road N       Magma Hideout 1F SE
#  21              R111 Winstrate House  Meteor Falls B1F Right S
#  24                   Verdanturf Mart  Abandoned Ship 1F Left S
#  26         Verdanturf Rusturf Tunnel               Mossdeep NE
#  27                     Verdanturf SW  Fallarbor Move Relearner
#  28                      Verdanturf S   Abandoned Ship Rooms SE
#  29                     Verdanturf SE     Mauville Gym Interior,
#  61   05: Fallarbor/Lavaridge              05: Destination
#  0          Fallarbor Contest                   Lilycove W
#  1    Fallarbor Fossil Maniac            Meteor Falls 1F S
#  2             Fallarbor Mart  Victory Road B1F SW Room NE
#  3   Fallarbor Move Relearner                Verdanturf SW
#  4       Fallarbor Pokecenter       Aqua Hideout Warps 2 W
#  5                Fallarbor S           Magma Hideout 3F S
#  7              R111 Old Lady    Aqua Hideout B1F S Room E
#  8          R112 Fiery Path N                 Fortree Mart
#  9               R114 Lanette          R109 Seashore House
#  10         R114 Meteor Falls           Mt Pyre 5F Ceiling
#  15             Lavaridge Gym                     Dead-End
#  16       Lavaridge Herb Shop        Seafloor Cavern R1 SW
#  17            Lavaridge Mart           Magma Hideout 1F C
#  18      Lavaridge Pokecenter                 Dewford Hall
#  19              Lavaridge SE          Granite Cave B1F NE
#  20         R112 Fiery Path S        Seafloor Cavern R2 SE
#  21          R112 Jagged Pass             Rusturf Tunnel E
#  22          R112 Mt. Chimney        Mauville Pokecenter W,
#  61   06: Fortree/Lilycove                06: Destination
#  0             Fortree Gym         Petalburg Pokecenter S
#  1            Fortree Mart              R112 Fiery Path N
#  2      Fortree Pokecenter               Lilycove Contest
#  3              Fortree NE       Department Store 4F Down
#  4             Fortree NNE                       E4 Drake
#  5             Fortree NNW                          Ho-oh
#  7              Fortree SE                  Sootopolis E2
#  8              Fortree SW      Jagged Pass Magma Hideout
#  9          R120 Registeel         Aqua Hideout Warps 4 C
#  11  Lilycove Aqua Hideout                Mt Pyre 2F Hole
#  12       Lilycove Contest             Fortree Pokecenter
#  14         Lilycove Motel                Sky Pillar 4F C
#  15  Lilycove Move Deleter        Fallarbor Mart Interior
#  16    Lilycove Pokecenter                      E4 Glacia
#  17     Lilycove Submarine              Granite Cave 1F S
#  19             Lilycove W              Fallarbor Contest
#  20            Lilycove SW        Pacifidlog Pokecenter S
#  21            Lilycove NE  Abandoned Ship 1F Left Stairs
#  22             Lilycove E     Abandoned Ship 1F Right SW,
#  61         07: Mossdeep              07: Destination
#  0          Mossdeep Gym       Aqua Hideout Warps 2 E
#  1         Mossdeep Mart         Seafloor Cavern R5 S
#  2   Mossdeep Pokecenter        Seafloor Cavern R3 NE
#  4           Mossdeep NW  Aqua Hideout B1F NE Room SE
#  5            Mossdeep W       Aqua Hideout Warps 4 W
#  6            Mossdeep N       Aqua Hideout Warps 3 W
#  7            Mossdeep S          Victory Road B1F SE
#  8           Mossdeep NE    Verdanturf Rusturf Tunnel
#  9           Mossdeep SE      Aqua Hideout Warps 1 SE,
#  61         08: Pacifidlog           08: Destination
#  0           Pacifidlog NE           E4 Pokecenter S
#  1           Pacifidlog NW              Petalburg SE
#  2   Pacifidlog Pokecenter    Department Store 5F Up
#  3            Pacifidlog S             Jagged Pass S
#  5           Pacifidlog SW  Meteor Falls B1F Left SW,
#  61         09: Sootopolis           09: Destination
#  0   Sootopolis Pokecenter        Granite Cave B2F E
#  1           Sootopolis E1     Mossdeep Pokecenter S
#  2           Sootopolis E2                Fortree SE
#  3           Sootopolis E3        Petalburg Woods SW
#  4           Sootopolis E4        Mt Pyre 4F Ceiling
#  5           Sootopolis E5  Department Store 3F Down
#  7         Sootopolis Mart           Mt Pyre 3F Hole
#  10          Sootopolis W2                    Regice
#  11          Sootopolis W3  Abandoned Ship 1F Left N,
#  61 10: Petalburg Woods        10: Destination
#  0    Petalburg Woods N  Seafloor Cavern R1 SE
#  1   Petalburg Woods SE          Rustboro Mart
#  2   Petalburg Woods SW          Sootopolis E3,
#  61 11: Rusturf Tunnel           11: Destination
#  0    Rusturf Tunnel E          R112 Jagged Pass
#  1    Rusturf Tunnel S            Petalburg Mart
#  2    Rusturf Tunnel W  Meteor Falls B1F Right W,
#  61     12: Granite Cave         12: Destination
#  1     Granite Cave 1F S      Lilycove Submarine
#  2    Granite Cave 1F SE      Victory Road B1F S
#  6   Granite Cave B1F NE            Lavaridge SE
#  7   Granite Cave B1F NW  Petalburg Pokecenter W
#  8   Granite Cave B1F SE           Mauville Mart
#  10   Granite Cave B2F E   Sootopolis Pokecenter,
#  61             13: Abandoned Ship       13: Destination
#  0     Abandoned Ship 1F Left Exit     Mirage Tower 2F N
#  1        Abandoned Ship 1F Left N         Sootopolis W3
#  2        Abandoned Ship 1F Left S       Verdanturf Mart
#  3   Abandoned Ship 1F Left Stairs           Lilycove NE
#  5    Abandoned Ship 1F Right Exit      Sky Pillar 4F Up
#  10     Abandoned Ship 1F Right SW            Lilycove E
#  12        Abandoned Ship Rooms NE  Seafloor Cavern R6 N
#  14        Abandoned Ship Rooms SE          Verdanturf S
#  23          Abandoned Ship B1F SW   Mauville Pokecenter,
#  61            14: Jagged Pass 14: Destination
#  1   Jagged Pass Magma Hideout      Fortree SW
#  2               Jagged Pass S    Pacifidlog S,
#  61          15: Meteor Falls          15: Destination
#  0          Meteor Falls 1F E              Rustboro SE
#  2          Meteor Falls 1F S  Fallarbor Fossil Maniac
#  11  Meteor Falls B1F Left SW            Pacifidlog SW
#  13  Meteor Falls B1F Right N                     Surf
#  14  Meteor Falls B1F Right S     R111 Winstrate House
#  15  Meteor Falls B1F Right W         Rusturf Tunnel W,
#  61   16: Mirage Tower              16: Destination
#  2   Mirage Tower 2F N  Abandoned Ship 1F Left Exit,
#  61  17: Route 119/123         17: Destination
#  2   R123 Berry Master  Aqua Hideout Warps 1 S,
#  61           18: Mt Pyre              18: Destination
#  5   Mt Pyre 2F Ceiling 1             Slateport Museum
#  7        Mt Pyre 2F Down                        Lugia
#  8        Mt Pyre 2F Hole        Lilycove Aqua Hideout
#  9          Mt Pyre 2F Up         Seafloor Cavern R1 N
#  13       Mt Pyre 3F Hole              Sootopolis Mart
#  14         Mt Pyre 3F Up                 Mauville Gym
#  16    Mt Pyre 4F Ceiling                Sootopolis E4
#  17       Mt Pyre 4F Down        Seafloor Cavern R6 SE
#  18       Mt Pyre 4F Hole                   Dewford NE
#  19         Mt Pyre 4F Up  Victory Road B1F SW Room SW
#  21    Mt Pyre 5F Ceiling            R114 Meteor Falls
#  22     Mt Pyre 5F Hole E                         Dive
#  23    Mt Pyre 5F Hole SE         Dewford Granite Cave,
#  Empty DataFrame
#  Columns: [19: Surf Hub, 19: Destination]
#  Index: [],
#  61    20: Magma Hideout         20: Destination
#  0    Magma Hideout 1F C          Lavaridge Mart
#  1   Magma Hideout 1F SE       R110 Cycle Road N
#  2   Magma Hideout 1F SW                Strength
#  8    Magma Hideout 3F C         E4 Pokecenter W
#  10   Magma Hideout 3F S  Fallarbor Pokecenter S,
#  61             21: Aqua Hideout           21: Destination
#  0    Aqua Hideout B1F NE Room N              Petalburg SW
#  1   Aqua Hideout B1F NE Room SE               Mossdeep NW
#  2   Aqua Hideout B1F NE Room SW                Dewford SE
#  4     Aqua Hideout B1F S Room E             R111 Old Lady
#  5    Aqua Hideout B1F S Room NW         Oldale Pokecenter
#  6    Aqua Hideout B1F S Room SW  Department Store 5F Down
#  8            Aqua Hideout B2F E                  Dead-End
#  9           Aqua Hideout B2F NW         Slateport Contest
#  10          Aqua Hideout B2F SW   Slateport Mart Interior
#  12       Aqua Hideout Warps 1 N     Mossdeep Pokecenter W
#  13       Aqua Hideout Warps 1 S         R123 Berry Master
#  14      Aqua Hideout Warps 1 SE               Mossdeep SE
#  15      Aqua Hideout Warps 1 SW    Department Store 4F Up
#  17       Aqua Hideout Warps 2 C               Dewford Gym
#  18       Aqua Hideout Warps 2 E              Mossdeep Gym
#  19       Aqua Hideout Warps 2 W      Fallarbor Pokecenter
#  21       Aqua Hideout Warps 3 C           Contest Hall NW
#  23       Aqua Hideout Warps 3 W                Mossdeep N
#  25       Aqua Hideout Warps 4 C            R120 Registeel
#  26       Aqua Hideout Warps 4 E     Lilycove Pokecenter S
#  27       Aqua Hideout Warps 4 W                Mossdeep W,
#  61 22: Lilycove Contest Hall         22: Destination
#  1            Contest Hall NW  Aqua Hideout Warps 3 C
#  2             Contest Hall S  Slateport Pokecenter W,
#  61 23: Lilycove Department Store             23: Destination
#  0       Department Store 1F Exit            Sky Pillar 1F Up
#  3         Department Store 2F Up     Sootopolis Pokecenter W
#  4       Department Store 3F Down               Sootopolis E5
#  5         Department Store 3F Up                     Groudon
#  6       Department Store 4F Down                  Fortree NE
#  7         Department Store 4F Up     Aqua Hideout Warps 1 SW
#  8       Department Store 5F Down  Aqua Hideout B1F S Room SW
#  9         Department Store 5F Up       Pacifidlog Pokecenter,
#  61    24: Seafloor Cavern          24: Destination
#  0    Seafloor Cavern R1 N            Mt Pyre 2F Up
#  1   Seafloor Cavern R1 SE        Petalburg Woods N
#  2   Seafloor Cavern R1 SW      Lavaridge Herb Shop
#  6   Seafloor Cavern R2 SE        R112 Fiery Path S
#  8    Seafloor Cavern R3 C   Mauville Mart Interior
#  9   Seafloor Cavern R3 NE      Mossdeep Pokecenter
#  11   Seafloor Cavern R3 S   Lavaridge Gym Interior
#  20   Seafloor Cavern R5 S            Mossdeep Mart
#  22   Seafloor Cavern R6 N  Abandoned Ship Rooms NE
#  23  Seafloor Cavern R6 SE          Mt Pyre 4F Down
#  24  Seafloor Cavern R6 SW         Sky Pillar 2F Up,
#  61          25: Pokecenters         25: Destination
#  2    Petalburg Pokecenter S             Fortree Gym
#  3    Petalburg Pokecenter W     Granite Cave B1F NW
#  4     Rustboro Pokecenter S              Mauville S
#  8    Slateport Pokecenter S      Rustboro Cut House
#  9    Slateport Pokecenter W          Contest Hall S
#  10    Mauville Pokecenter S     Victory Road B2F NE
#  11    Mauville Pokecenter W        R112 Mt. Chimney
#  14   Fallarbor Pokecenter S      Magma Hideout 3F S
#  15   Fallarbor Pokecenter W       R110 Cycle Road S
#  18    Lilycove Pokecenter S  Aqua Hideout Warps 4 E
#  19    Lilycove Pokecenter W          Slateport Mart
#  20    Mossdeep Pokecenter S           Sootopolis E1
#  21    Mossdeep Pokecenter W  Aqua Hideout Warps 1 N
#  22  Sootopolis Pokecenter S     Rustboro Pokecenter
#  23  Sootopolis Pokecenter W  Department Store 2F Up
#  24  Pacifidlog Pokecenter S             Lilycove SW
#  25  Pacifidlog Pokecenter W   Rustboro Gym Interior,
#  61             26: Victory Road        26: Destination
#  1            Victory Road B1F S     Granite Cave 1F SE
#  2           Victory Road B1F SE             Mossdeep S
#  5   Victory Road B1F SW Room NE         Fallarbor Mart
#  6   Victory Road B1F SW Room SW          Mt Pyre 4F Up
#  9           Victory Road B2F NE  Mauville Pokecenter S,
#  Empty DataFrame
#  Columns: [27: Waterfall Hub, 27: Destination]
#  Index: [],
#  61       28: E4 Pokecenter       28: Destination
#  0          E4 Pokecenter S         Pacifidlog NE
#  2          E4 Pokecenter W    Magma Hideout 3F C
#  4   Lavaridge Pokecenter S  Slateport Pokecenter
#  5   Lavaridge Pokecenter W              Dead-End
#  6   Lavaridge Pokecenter N       Sky Pillar 3F C,
#  Empty DataFrame
#  Columns: [29: Navel Rock, 29: Destination]
#  Index: [],
#  Empty DataFrame
#  Columns: [30: Dive Hub, 30: Destination]
#  Index: [],
#  61    31: Sky Pillar               31: Destination
#  1   Sky Pillar 1F Up      Department Store 1F Exit
#  3   Sky Pillar 2F Up         Seafloor Cavern R6 SW
#  6    Sky Pillar 3F C        Lavaridge Pokecenter N
#  8   Sky Pillar 4F Up  Abandoned Ship 1F Right Exit
#  9    Sky Pillar 4F C                Lilycove Motel,
#  61       25-0: Pokecenters      25: Destination
#  2   Petalburg Pokecenter S          Fortree Gym
#  3   Petalburg Pokecenter W  Granite Cave B1F NW,
#  61      25-1: Pokecenters 25: Destination
#  4   Rustboro Pokecenter S      Mauville S,
#  61       25-2: Pokecenters     25: Destination
#  8   Slateport Pokecenter S  Rustboro Cut House
#  9   Slateport Pokecenter W      Contest Hall S,
#  61      25-3: Pokecenters      25: Destination
#  10  Mauville Pokecenter S  Victory Road B2F NE
#  11  Mauville Pokecenter W     R112 Mt. Chimney,
#  61       25-4: Pokecenters     25: Destination
#  14  Fallarbor Pokecenter S  Magma Hideout 3F S
#  15  Fallarbor Pokecenter W   R110 Cycle Road S,
#  61      25-5: Pokecenters         25: Destination
#  18  Lilycove Pokecenter S  Aqua Hideout Warps 4 E
#  19  Lilycove Pokecenter W          Slateport Mart,
#  61      25-6: Pokecenters         25: Destination
#  20  Mossdeep Pokecenter S           Sootopolis E1
#  21  Mossdeep Pokecenter W  Aqua Hideout Warps 1 N,
#  61        25-7: Pokecenters         25: Destination
#  22  Sootopolis Pokecenter S     Rustboro Pokecenter
#  23  Sootopolis Pokecenter W  Department Store 2F Up,
#  61        25-8: Pokecenters        25: Destination
#  24  Pacifidlog Pokecenter S            Lilycove SW
#  25  Pacifidlog Pokecenter W  Rustboro Gym Interior]

# %%
import copy

def graph_algo(src, dest, graph):
    if src == dest:
        return True
    src_node = graph.nodes[src]
    src_node['visited'] = True
    queue = [src_node]

    while len(queue) > 0:
        # print('Queue: ', sorted([x['node_name'] for x in queue]))
        current = queue.pop(0)
        # if current['node_name'] == dest:
            # print('Current: %s equals Dest: %s' % (current['node_name'], dest))
            # print('### FOUND IT ####')
            # print(current)
        for t in current['transitions']:
            node_name = graph.edges.get(t['destination'])
            # the node might not exist: Strength, one-way, the 32: Marts thing is not really present in the sheet.
            if node_name:
                node = graph.nodes[node_name]
                if node['visited']:
                    continue
                # add previous
                prev = node['previous']
                if prev.get(current['node_name']):
                    prev[current['node_name']].append(t)
                else:
                    prev[current['node_name']] = [t]
                # mark visited
                # if not node['visited']:
                    # node['visited'] = True
                    # queue.append(node)
                node['visited'] = True
                queue.append(node)
    return graph.nodes[dest]

graph_copy = copy.deepcopy(graph)
dest = graph_algo('Slateport/Mauville/Verdanturf', 'Rustboro', graph_copy)
dest

# %%
graph_copy.nodes['Pokecenters']['previous']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14800/3090450052.py in <module>
# ----> 1 graph_copy.nodes['Pokecenters']['previous']
#
# NameError: name 'graph_copy' is not defined

# %%
reachable = set()

def reach(node_name, graph, depth_max):
    node = graph.nodes[node_name]
    prev = node['previous'].keys()
    # print(prev)
    for k in prev:
        reachable.add(k)
        if depth_max > 0:
            reach(k, graph, depth_max-1)
reach('Rustboro', graph_copy, 5)
len(reachable)

# %%
name = dest['node_name']
the_node = graph_copy.nodes[name]
prev = the_node['previous']
flat_prev = [[(node[0], trans)] for node in list(prev.items())
    for trans in node[1]]

def list_prev(node_name):
    node = graph_copy.nodes[node_name]
    flat_prev = [(node[0], trans) for node in list(node['previous'].items())
                                    for trans in node[1]]
    
    
flat_prev[0]

# %%
def flatten_prev(node_name, graph):
    node = graph.nodes[node_name]
    return [(node[0], trans) for node in list(node['previous'].items())
                        for trans in node[1]]
def list_prev(node_name, graph):
    node = graph.nodes[node_name]
    flat_prev = flatten_prev(node_name, graph)
    return flat_prev
    

print(flatten_prev('Rustboro', graph_copy)[0])
print(flatten_prev('Pokecenters', graph_copy)[0])
list_prev('Slateport/Mauville/Verdanturf', graph_copy)
